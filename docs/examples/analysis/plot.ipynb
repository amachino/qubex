# %%
import numpy as np
import qubex as qx

# %%
times = np.linspace(0, 1, 100)
cos_data = np.cos(2 * np.pi * 5 * times) + 0.1 * np.random.randn(len(times))

# %%
qx.viz.plot(
    y=cos_data,
    title="Cosine wave",
    ylabel="Amplitude",
)

# %%
fig = qx.viz.plot(
    x=times,
    y=cos_data,
    title="Cosine wave",
    xlabel="Time",
    ylabel="Amplitude",
    width=800,
    height=400,
    return_figure=True,
)

fig.show() # type: ignore

# %%
qx.viz.plot_fft(
    times,
    cos_data,
)

# %%
data = np.random.randn(300) + 1j * np.random.randn(300)

qx.viz.plot_waveform(np.concatenate([data, 5 + data, data]))

# %%
qx.viz.plot_state_distribution(
    {
        "Q00": data + 2 + 2j,
        "Q01": data + 2 - 2j,
    },
)
